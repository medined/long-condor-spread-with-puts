# %%
import pandas as pd

# %%
df = pd.read_csv('data-lcs.csv')
df.shape
# Out:
# (3717, 9)

# %%
df.sort_values('ratio', ascending=False, inplace=True)
df.head(n=20)
# Out:
#      symbol expiration_date      p1      p2      p3      p4  max_loss  \
# 2800   ROKU      2021-06-11   345.0   347.5   350.0   352.5       2.0
# 3279   TSIA      2021-06-18    10.0    12.5    15.0    17.5       2.0
# 226    AMZN      2021-06-04  3220.0  3225.0  3230.0  3235.0       5.0
# 3010   SPCE      2021-06-11    31.0    32.0    33.0    34.0       1.0
# 1231   FATE      2021-06-18    75.0    80.0    85.0    90.0       5.0
# 24     ABBV      2021-06-25   113.0   114.0   115.0   116.0       1.0
# 3388   UPST      2021-06-18   145.0   150.0   155.0   160.0       5.0
# 3467    VMW      2021-06-11   157.5   160.0   162.5   165.0       3.0
# 3281   TSLA      2021-06-11   625.0   627.5   630.0   632.5       3.0
# 1645   HYLN      2021-06-11    10.5    11.0    11.5    12.0       1.0
# 677    CHPT      2021-06-18    24.0    24.5    25.0    25.5       1.0
# 1617   HSBC      2021-06-25    32.0    32.5    33.0    33.5       1.0
# ...
